# %% [markdown]
# # Craw Stocks

# %%
import requests, re, time, os, warnings
import datetime, utils
import pandas as pd
import numpy as np

warnings.filterwarnings('ignore')

# %%
# 先定義方法將下載下的格式轉成我們想要的DataFrame格式
def to_pd(date, text):
    df = None
    try:
        # 用換行符號將文字檔分隔, 並過濾掉不符我們預想的內容
        lines = [line for line in text.split('\n') if len(line.split('",'))==17 and line[0]!='=']
        # 第一行作為columns, 只拿出其中的中文字, 然後用columns製作空的DataFrame
        columns = [re.search('[\u4e00-\u9fff]*', i.replace('\"', '')).group() for i in lines[0].split('","')]
        df = pd.DataFrame(columns=columns)
        
        # 將除第一行之外的一個一個塞到DataFrame中, 並把內容我們不要的符號replace掉
        for idx, line in enumerate(lines):
            if idx==0 :
                continue
            df.loc[idx-1, :] = [i.replace('\"',"").replace(',\r','') for i in line.split('","')]
        
        # 最後調整一下DateFrame的格式後回傳
        df = df.set_index('證券代號')
        df.loc[:,['成交金額', '成交股數', '成交筆數']] = df.loc[:,['成交金額', '成交股數', '成交筆數']].replace(',', '', regex=True)
        print(date, 'success.')
    except IndexError as e:
        print(date, e)
        
    return df

# %%
def crawl_price(date):
    # 把header先設定好, 因為用get取資料比較快, 就不使用字典, 直接放在list中, 可以用sparse語法塞到url中
    data = ['response', 'csv', 'date', date.replace('-',''), 'type', 'ALL']
    url = 'http://www.twse.com.tw/exchangeReport/MI_INDEX?{}={}&{}={}&{}={}'.format(*data)
    
    # 用get方法給出請求拿資料, 取出文字後丟方法轉成dataframe, 最後回傳
    with requests.get(url) as r:
        text = r.text
        df = to_pd(date, text)
        return df

# %%
# 定義一個產生器, 這種方法可以確保我們中斷還是能順利把資料產出
def create_crawl(n_days, date=None, data=None):
    # 參數設定為None, 並方法內判斷, 這能夠讓我們有較大的彈性決定要不要傳入參數
    if not data:
        data = {}
    if not date:
        date = datetime.datetime.now()
    
    # 設定迴圈呼叫前面定義的方法, 並每次執行完就把產出直接回傳出去
    while n_days > 0:
        date_string = date.isoformat()[:10]
        df = crawl_price(date_string)
        date -= datetime.timedelta(days=1)
        n_days -= 1
        yield date, date_string, df

# %%
# 最後再寫一個方法來執行方法, 主要是用來捕捉錯誤以及設定暫停
def start_craw(n_days, date=None):
    # 特別注意參數中並沒有設定data, 這代表我們並沒有將data傳進方法中, 同時我們也沒有回傳data
    # 其實python在方法中還是會自動調用global的物件, 透過這種寫法我們可以在下面的迴圈中不斷的更新data
    # 即使發生了不可預期的錯誤, 只要python環境還沒有結束, data就可以持續留在記憶體中, 且不需要等到整個方法結束才能回傳
    if not date:
        date = datetime.datetime.now()
    
    # 建立初始的產生器物件, 並設定每次迴圈的動作
    generator = create_crawl(n_days=n_days, date=date, data=data)
    while True:
        # 建議由暫停起手, 確保每次都會暫停, 有效防止對方主機檔IP
        time.sleep(5)
        # try我們想要執行的內容, 呼叫產生器, 然後存到字典中
        try:
            new_date, date_string, df = generator.send(None)
            data[date_string] = df
        # 由於這邊對方主機有時候會拒絕連線, 因此要寫我們從被拒絕的地方繼續嘗試
        except requests.adapters.ConnectionError as e:
            print(e)
            generator = create_crawl(n_days=n_days-(date - new_date).days, date=new_date, data=data)
        # 產生器物件迭代完畢會拋出StopIteration錯誤, 捕捉起來告訴自己迭代完畢即可
        except StopIteration as e:
            print('Total Finished.')
            break

# %%
# 這個寫法可以特別記一下, 主要是建立py檔時使用, 當該程式是主要執行程式時執行
if __name__ == '__main__':
    # 建立空字典
    data={}
    # 執行爬蟲動作
    start_craw(365, date = datetime.datetime.now())
    # 將物件用二進位的方式存起來, 可以看一下utils內語法, 預設使用最高壓縮協定, 能夠減少一半以上空間占用
    utils.save_obj(data, os.path.join('data', 'stock.pkl'))
# Out:
# 2018-09-15 list index out of range
# 2018-09-14 success.
# 2018-09-13 success.
# 2018-09-12 success.
# 2018-09-11 success.
# 2018-09-10 success.
# 2018-09-09 list index out of range
# 2018-09-08 list index out of range
# 2018-09-07 success.
# 2018-09-06 success.
# 2018-09-05 success.
# 2018-09-04 success.
# 2018-09-03 success.
# 2018-09-02 list index out of range
# 2018-09-01 list index out of range
# 2018-08-31 success.
# 2018-08-30 success.
# 2018-08-29 success.
# 2018-08-28 success.
# 2018-08-27 success.
# 2018-08-26 list index out of range
# 2018-08-25 list index out of range
# 2018-08-24 success.
# 2018-08-23 success.
# 2018-08-22 success.
# 2018-08-21 success.
# 2018-08-20 success.
# 2018-08-19 list index out of range
# 2018-08-18 list index out of range
# 2018-08-17 success.
# 2018-08-16 success.
# 2018-08-15 success.
# 2018-08-14 success.
# 2018-08-13 success.
# 2018-08-12 list index out of range
# 2018-08-11 list index out of range
# 2018-08-10 success.
# 2018-08-09 success.
# 2018-08-08 success.
# 2018-08-07 success.
# 2018-08-06 success.
# 2018-08-05 list index out of range
# 2018-08-04 list index out of range
# 2018-08-03 success.
# 2018-08-02 success.
# 2018-08-01 success.
# 2018-07-31 success.
# 2018-07-30 success.
# 2018-07-29 list index out of range
# 2018-07-28 list index out of range
# 2018-07-27 success.
# 2018-07-26 success.
# 2018-07-25 success.
# 2018-07-24 success.
# 2018-07-23 success.
# 2018-07-22 list index out of range
# 2018-07-21 list index out of range
# 2018-07-20 success.
# 2018-07-19 success.
# 2018-07-18 success.
# 2018-07-17 success.
# 2018-07-16 success.
# 2018-07-15 list index out of range
# 2018-07-14 list index out of range
# 2018-07-13 success.
# 2018-07-12 success.
# 2018-07-11 success.
# 2018-07-10 success.
# 2018-07-09 success.
# 2018-07-08 list index out of range
# 2018-07-07 list index out of range
# 2018-07-06 success.
# 2018-07-05 success.
# 2018-07-04 success.
# 2018-07-03 success.
# 2018-07-02 success.
# 2018-07-01 list index out of range
# 2018-06-30 list index out of range
# 2018-06-29 success.
# 2018-06-28 success.
# 2018-06-27 success.
# HTTPConnectionPool(host='www.twse.com.tw', port=80): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20180626&type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002737E74EE10>: Failed to establish a new connection: [WinError 10061] 無法連線，因為目標電腦拒絕連線。',))
# HTTPConnectionPool(host='www.twse.com.tw', port=80): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20180626&type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002737EF2EDA0>: Failed to establish a new connection: [WinError 10061] 無法連線，因為目標電腦拒絕連線。',))
# HTTPConnectionPool(host='www.twse.com.tw', port=80): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20180626&type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002737F1D3470>: Failed to establish a new connection: [WinError 10061] 無法連線，因為目標電腦拒絕連線。',))
# HTTPConnectionPool(host='www.twse.com.tw', port=80): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20180626&type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002737E0D7EF0>: Failed to establish a new connection: [WinError 10061] 無法連線，因為目標電腦拒絕連線。',))
# HTTPConnectionPool(host='www.twse.com.tw', port=80): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20180626&type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002737E74E630>: Failed to establish a new connection: [WinError 10061] 無法連線，因為目標電腦拒絕連線。',))
# 2018-06-26 success.
# 2018-06-25 success.
# 2018-06-24 list index out of range
# 2018-06-23 list index out of range
# 2018-06-22 success.
# 2018-06-21 success.
# 2018-06-20 success.
# 2018-06-19 success.
# 2018-06-18 list index out of range
# 2018-06-17 list index out of range
# 2018-06-16 list index out of range
# 2018-06-15 success.
# 2018-06-14 success.
# 2018-06-13 success.
# 2018-06-12 success.
# 2018-06-11 success.
# 2018-06-10 list index out of range
# 2018-06-09 list index out of range
# 2018-06-08 success.
# 2018-06-07 success.
# 2018-06-06 success.
# 2018-06-05 success.
# 2018-06-04 success.
# 2018-06-03 list index out of range
# 2018-06-02 list index out of range
# 2018-06-01 success.
# 2018-05-31 success.
# 2018-05-30 success.
# 2018-05-29 success.
# 2018-05-28 success.
# 2018-05-27 list index out of range
# 2018-05-26 list index out of range
# 2018-05-25 success.
# 2018-05-24 success.
# 2018-05-23 success.
# 2018-05-22 success.
# 2018-05-21 success.
# 2018-05-20 list index out of range
# 2018-05-19 list index out of range
# 2018-05-18 success.
# 2018-05-17 success.
# 2018-05-16 success.
# 2018-05-15 success.
# 2018-05-14 success.
# 2018-05-13 list index out of range
# 2018-05-12 list index out of range
# 2018-05-11 success.
# 2018-05-10 success.
# 2018-05-09 success.
# 2018-05-08 success.
# 2018-05-07 success.
# 2018-05-06 list index out of range
# 2018-05-05 list index out of range
# 2018-05-04 success.
# 2018-05-03 success.
# 2018-05-02 success.
# 2018-05-01 list index out of range
# 2018-04-30 success.
# 2018-04-29 list index out of range
# 2018-04-28 list index out of range
# 2018-04-27 success.
# 2018-04-26 success.
# 2018-04-25 success.
# 2018-04-24 success.
# 2018-04-23 success.
# 2018-04-22 list index out of range
# 2018-04-21 list index out of range
# 2018-04-20 success.
# 2018-04-19 success.
# 2018-04-18 success.
# 2018-04-17 success.
# 2018-04-16 success.
# 2018-04-15 list index out of range
# 2018-04-14 list index out of range
# 2018-04-13 success.
# 2018-04-12 success.
# 2018-04-11 success.
# 2018-04-10 success.
# 2018-04-09 success.
# 2018-04-08 list index out of range
# 2018-04-07 list index out of range
# 2018-04-06 list index out of range
# 2018-04-05 list index out of range
# 2018-04-04 list index out of range
# 2018-04-03 success.
# 2018-04-02 success.
# 2018-04-01 list index out of range
# 2018-03-31 success.
# 2018-03-30 success.
# 2018-03-29 success.
# 2018-03-28 success.
# 2018-03-27 success.
# 2018-03-26 success.
# 2018-03-25 list index out of range
# 2018-03-24 list index out of range
# 2018-03-23 success.
# 2018-03-22 success.
# 2018-03-21 success.
# 2018-03-20 success.
# 2018-03-19 success.
# 2018-03-18 list index out of range
# 2018-03-17 list index out of range
# 2018-03-16 success.
# 2018-03-15 success.
# 2018-03-14 success.
# 2018-03-13 success.
# 2018-03-12 success.
# 2018-03-11 list index out of range
# 2018-03-10 list index out of range
# 2018-03-09 success.
# 2018-03-08 success.
# 2018-03-07 success.
# 2018-03-06 success.
# 2018-03-05 success.
# 2018-03-04 list index out of range
# 2018-03-03 list index out of range
# 2018-03-02 success.
# 2018-03-01 success.
# 2018-02-28 list index out of range
# 2018-02-27 success.
# 2018-02-26 success.
# 2018-02-25 list index out of range
# 2018-02-24 list index out of range
# 2018-02-23 success.
# 2018-02-22 success.
# 2018-02-21 success.
# 2018-02-20 list index out of range
# 2018-02-19 list index out of range
# 2018-02-18 list index out of range
# 2018-02-17 list index out of range
# 2018-02-16 list index out of range
# 2018-02-15 list index out of range
# 2018-02-14 list index out of range
# 2018-02-13 list index out of range
# 2018-02-12 success.
# 2018-02-11 list index out of range
# 2018-02-10 list index out of range
# 2018-02-09 success.
# 2018-02-08 success.
# 2018-02-07 success.
# 2018-02-06 success.
# 2018-02-05 success.
# 2018-02-04 list index out of range
# 2018-02-03 list index out of range
# 2018-02-02 success.
# 2018-02-01 success.
# 2018-01-31 success.
# 2018-01-30 success.
# 2018-01-29 success.
# 2018-01-28 list index out of range
# 2018-01-27 list index out of range
# 2018-01-26 success.
# 2018-01-25 success.
# 2018-01-24 success.
# 2018-01-23 success.
# 2018-01-22 success.
# 2018-01-21 list index out of range
# 2018-01-20 list index out of range
# 2018-01-19 success.
# 2018-01-18 success.
# 2018-01-17 success.
# 2018-01-16 success.
# 2018-01-15 success.
# 2018-01-14 list index out of range
# 2018-01-13 list index out of range
# 2018-01-12 success.
# 2018-01-11 success.
# 2018-01-10 success.
# 2018-01-09 success.
# 2018-01-08 success.
# 2018-01-07 list index out of range
# 2018-01-06 list index out of range
# 2018-01-05 success.
# 2018-01-04 success.
# 2018-01-03 success.
# 2018-01-02 success.
# 2018-01-01 list index out of range
# 2017-12-31 list index out of range
# 2017-12-30 list index out of range
# 2017-12-29 success.
# 2017-12-28 success.
# 2017-12-27 success.
# 2017-12-26 success.
# 2017-12-25 success.
# 2017-12-24 list index out of range
# 2017-12-23 list index out of range
# 2017-12-22 success.
# 2017-12-21 success.
# 2017-12-20 success.
# 2017-12-19 success.
# 2017-12-18 success.
# 2017-12-17 list index out of range
# 2017-12-16 list index out of range
# 2017-12-15 success.
# 2017-12-14 success.
# 2017-12-13 success.
# 2017-12-12 success.
# 2017-12-11 success.
# 2017-12-10 list index out of range
# 2017-12-09 list index out of range
# 2017-12-08 success.
# 2017-12-07 success.
# 2017-12-06 success.
# 2017-12-05 success.
# 2017-12-04 success.
# 2017-12-03 list index out of range
# 2017-12-02 list index out of range
# 2017-12-01 success.
# 2017-11-30 success.
# 2017-11-29 success.
# 2017-11-28 success.
# 2017-11-27 success.
# 2017-11-26 list index out of range
# 2017-11-25 list index out of range
# 2017-11-24 success.
# 2017-11-23 success.
# 2017-11-22 success.
# 2017-11-21 success.
# 2017-11-20 success.
# 2017-11-19 list index out of range
# 2017-11-18 list index out of range
# 2017-11-17 success.
# 2017-11-16 success.
# 2017-11-15 success.
# 2017-11-14 success.
# 2017-11-13 success.
# 2017-11-12 list index out of range
# 2017-11-11 list index out of range
# 2017-11-10 success.
# 2017-11-09 success.
# 2017-11-08 success.
# 2017-11-07 success.
# 2017-11-06 success.
# 2017-11-05 list index out of range
# 2017-11-04 list index out of range
# 2017-11-03 success.
# 2017-11-02 success.
# 2017-11-01 success.
# 2017-10-31 success.
# 2017-10-30 success.
# 2017-10-29 list index out of range
# 2017-10-28 list index out of range
# 2017-10-27 success.
# 2017-10-26 success.
# 2017-10-25 success.
# 2017-10-24 success.
# 2017-10-23 success.
# 2017-10-22 list index out of range
# 2017-10-21 list index out of range
# 2017-10-20 success.
# 2017-10-19 success.
# 2017-10-18 success.
# 2017-10-17 success.
# 2017-10-16 success.
# 2017-10-15 list index out of range
# 2017-10-14 list index out of range
# 2017-10-13 success.
# 2017-10-12 success.
# 2017-10-11 success.
# 2017-10-10 list index out of range
# 2017-10-09 list index out of range
# 2017-10-08 list index out of range
# 2017-10-07 list index out of range
# 2017-10-06 success.
# 2017-10-05 success.
# 2017-10-04 list index out of range
# 2017-10-03 success.
# 2017-10-02 success.
# 2017-10-01 list index out of range
# 2017-09-30 success.
# 2017-09-29 success.
# 2017-09-28 success.
# 2017-09-27 success.
# 2017-09-26 success.
# 2017-09-25 success.
# 2017-09-24 list index out of range
# 2017-09-23 list index out of range
# 2017-09-22 success.
# 2017-09-21 success.
# 2017-09-20 success.
# 2017-09-19 success.
# 2017-09-18 success.
# 2017-09-17 list index out of range
# 2017-09-16 list index out of range
# Total Finished.

# %%
# 偷看一下我們抓下來的資料, 裡面是每一天存一個dataframe, 透過這個結構我們可以拿出任何我們想要的訊息
data['2018-09-14']
# Out:
#          證券名稱      成交股數   成交筆數        成交金額     開盤價     最高價     最低價     收盤價 漲跌  \
# 證券代號
# 1101       台泥  13834200   6222   545879305   39.10   39.80   38.55   39.65  +
# 1102       亞泥  23391527  10885   884179826   37.25   38.40   37.05   37.80  +
# 1103       嘉泥    406983    149     5457518   13.35   13.50   13.30   13.35  -
# 1104       環泥    114070     79     2324025   20.30   20.45   20.30   20.40  +
# 1108       幸福    174202     29     1359995    7.84    7.84    7.78    7.78  -
# 1109       信大    179200     68     2678339   15.00   15.00   14.90   14.95  -
# 1110       東泥     70000     47      968350   14.00   14.00   13.75   13.95  -
# 1201       味全    633722    350    14170657   22.40   22.50   22.30   22.40  +
# 1203       味王     13445     18      343701   25.60   25.65   25.40   25.40  -
# 1210       大成   1585570   1120    58574967   36.85   37.10   36.70   37.00  +
# 1213       大飲     14019     12      175486   12.60   12.60   12.45   12.55  +
# 1215       卜蜂    422475    317    22031583   52.00   52.30   51.80   52.20  +
# 1216       統一   8072175   3648   609209233   75.40   75.90   75.20   75.40  +
# 1217      愛之味    336400    170     2548433    7.53    7.60    7.53    7.58  +
# 1218       泰山   6722283   2028   123905673   18.40   18.60   18.20   18.30  +
# 1219       福壽    744111     16    15262712   18.70   18.70   18.55   18.60  -
# 1220       台榮    184000     69     2175700   11.80   12.00   11.70   11.80
# 1225      福懋油      1500      4      128649   85.80   85.80   85.80   85.80  -
# 1227       佳格    521866    440    27302764   52.00   52.70   51.90   52.40  +
# 1229       聯華    931402    621    32775450   35.30   35.35   35.00   35.15
# 1231      聯華食    114396     95     4161019   36.30   36.50   36.20   36.50  +
# 1232      大統益     24751     38     2395694   96.80   96.90   96.70   96.70  -
# 1233       天仁     20159     19      779593   38.60   38.75   38.60   38.75  +
# 1234       黑松     81038     53     2507169   30.80   31.00   30.80   30.85  -
# 1235       興泰    560436     24    24239104   39.80   39.80   38.95   39.05  -
# 1236       宏亞     14402     16      233750   16.25   16.25   16.15   16.15  -
# 1256  鮮活果汁-KY     24300     27     3814550  156.50  158.50  156.50  156.50
# 1262    綠悅-KY    962470    618    28101926   29.55   29.85   29.00   29.10  -
# 1301       台塑   5636394   2665   631116128  113.00  113.00  111.50  112.00  -
# 1303       南亞   6277963   2455   527600392   84.60   84.60   83.80   84.00  -
# ...       ...       ...    ...         ...     ...     ...     ...     ... ..
# 9911       櫻花     96099     76     3650426   37.95   38.20   37.75   38.15  +
# 9912       偉聯     34272     24      305940    8.93    8.94    8.90    8.94  +
# 9914      美利達    454662    362    63356518  138.50  140.00  138.00  139.00
# 9917       中保    144959    135    12777772   88.00   88.40   87.90   88.40  +
# 9918      欣天然      4001      5      132833   33.45   33.45   32.95   33.45  -
# 9919      康那香     67000     46      762450   11.50   11.50   11.35   11.40
# 9921       巨大    535200    403    69233400  127.50  131.50  127.00  131.00  +
# 9924       福興     78000     73     2698750   34.90   34.90   34.40   34.70  -
# 9925       新保    336706    235    11825430   35.05   35.35   35.00   35.20  +
# 9926       新海      1000      1       40500   40.50   40.50   40.50   40.50  +
# 9927       泰銘    118879     92     4155500   34.45   35.20   34.45   34.90  +
# 9928       中視        46      3         226      --      --      --      --
# 9929       秋雨     11399      7      146847   12.85   12.90   12.85   12.90  +
# 9930     中聯資源     30179     28     1688495   55.90   56.10   55.90   56.10
# 9931       欣高      5000      3      160900   32.20   32.30   32.10   32.30  -
# 9933       中鼎   3226372   1822   160956453   49.70   50.10   49.25   49.35  -
# 9934       成霖    373450    230     6020011   16.20   16.25   15.90   16.20  +
# 9935      慶豐富    160050     73     2724062   17.00   17.10   16.85   17.10  +
# 9937       全國      5496     10      219388   40.00   40.00   39.90   39.90
# 9938       百和   2800456   1960   198179182   70.50   71.50   70.10   70.50  +
# 9939       宏全    490940    409    25484165   51.50   52.20   51.50   52.20  +
# 9940       信義    147595    135     5066670   34.25   34.65   34.00   34.25
# 9941       裕融    148349    128    15464145  104.00  105.00  104.00  104.00
# 9942       茂順    134020     92    10396170   78.00   78.30   76.90   77.00  -
# 9943      好樂迪     86250     74     5068499   59.00   59.00   58.60   58.70  -
# 9944       新麗     14000     12      227300   16.20   16.30   16.15   16.30  +
# 9945      潤泰新   5761301   2140   201339093   34.95   35.10   34.70   35.05  +
# 9946     三發地產    101284     72     1353877   13.30   13.50   13.30   13.30
# 9955       佳龍    373354    135     5195920   13.60   14.05   13.60   13.95  +
# 9958      世紀鋼  22993416  13658  1834892380   83.50   83.90   76.40   80.00  -
#
#       漲跌價差  最後揭示買價 最後揭示買量  最後揭示賣價 最後揭示賣量     本益比
# 證券代號
# 1101  0.55   39.65      1   39.70     39   11.49
# 1102  0.80   37.80     19   37.85     54   12.90
# 1103  0.05   13.35     49   13.40     20    6.15
# 1104  0.10   20.40      1   20.45     12   11.66
# 1108  0.04    7.78     32    7.84      5    0.00
# 1109  0.05   14.90     14   14.95      1    9.29
# 1110  0.05   13.85      1   13.95      9   63.41
# 1201  0.05   22.40      8   22.45     14   16.72
# 1203  0.20   25.35      1   25.50      1   13.58
# 1210  0.30   37.00      3   37.05     43   10.22
# 1213  0.15   12.45      2   12.55     10  156.88
# 1215  0.50   52.20      7   52.30     39   12.70
# 1216  0.40   75.40    175   75.50     34   10.59
# 1217  0.06    7.58     21    7.59     20   18.95
# 1218  0.20   18.30    114   18.35      3   16.64
# 1219  0.10   18.50      1   18.60     20   31.00
# 1220  0.00   11.75      8   11.80      3   20.34
# 1225  1.10   85.70      1   87.10      1   74.61
# 1227  0.50   52.40      7   52.50      5   19.34
# 1229  0.00   35.15     47   35.20      7   10.88
# 1231  0.30   36.45      1   36.50     20   12.50
# 1232  0.10   96.70      6   96.90     12   17.68
# 1233  0.25   38.65      4   38.80     11   19.09
# 1234  0.15   30.85      2   30.95      2   18.47
# 1235  0.45   39.05      1   39.25      3    9.89
# 1236  0.10   16.15      2   16.25      1   62.12
# 1256  0.00  156.50      1  157.50      1   13.02
# 1262  0.30   29.10     18   29.15      4    0.00
# 1301  0.50  111.50    465  112.00    909   12.12
# 1303  0.60   84.00    176   84.10      5   10.29
# ...    ...     ...    ...     ...    ...     ...
# 9911  0.20   38.00      2   38.15      1   10.66
# 9912  0.02    8.92      5    8.94      5   47.05
# 9914  0.00  139.00    176  139.50     71   46.18
# 9917  0.40   87.90      6   88.40     17   20.42
# 9918  0.05   33.00      1   33.45     12   21.17
# 9919  0.00   11.35     19   11.45     15   26.51
# 9921  3.50  130.00      3  131.00     52   25.39
# 9924  0.05   34.55      6   34.70      1   11.88
# 9925  0.20   35.15      2   35.20      2   15.30
# 9926  0.20   40.00      1   40.50      2   20.56
# 9927  0.55   34.90      5   34.95      3    8.45
# 9928  0.00    5.06      3    5.20      1    0.00
# 9929  0.05   12.85      6   12.90     20  117.27
# 9930  0.00   56.00      1   56.10      4   15.98
# 9931  0.10   32.00      2   32.40      1   15.68
# 9933  0.35   49.35      1   49.45      9   20.06
# 9934  0.15   16.15      6   16.20     44   12.09
# 9935  0.15   17.10      9   17.15      3   11.32
# 9937  0.00   39.85      2   39.90      4   15.77
# 9938  0.60   70.50     15   70.70     23   13.93
# 9939  0.70   52.00      1   52.20      8   12.08
# 9940  0.00   34.15     33   34.30     12   12.36
# 9941  0.00  104.00     12  104.50     18   11.67
# 9942  0.60   76.90      4   77.00     57   12.92
# 9943  0.30   58.70      4   58.80      2   10.10
# 9944  0.15   16.15      1   16.30     17   37.05
# 9945  0.25   35.00      2   35.05    136    3.65
# 9946  0.00   13.30      5   13.40      8    9.17
# 9955  0.05   13.90     39   13.95      6    0.00
# 9958  3.10   79.90     24   80.00     49  222.22
#
# [938 rows x 15 columns]
