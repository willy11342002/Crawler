# %% [markdown]
# # CrawSPBO

# %%
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException

# %%
import opencc

# %%
import pandas as pd
import re

# %%
# 由於網站定期由 js 動態生成, 我們直接使用 selenium
driver = webdriver.Chrome()
driver.get('http://bf.spbo1.com/')

# %%
# 觀察標籤, 發現需要的資料被放在三個 table 中, 但是共用一個表頭
# 於是我們一次取出三個 table, 並拿出表頭
tables = [driver.find_elements_by_css_selector(f'{tag} > table')[0] for tag in ['#bflive', '#bflive2', '#bflive3']]
columns = [td.text for td in tables[0].find_elements_by_css_selector('tbody > tr')[0].find_elements_by_css_selector('td')]
print(columns)
# Out:
# ['', '11月06日', 'KO时间', '主场球队', '比分', '客场球队', '半场', '资料', '主', '让球', '客']

# %%
# 取出 table 的內容, 由於該網站更新時會清除重建 table 內的物件
# 因此我們需要捕捉 StaleElementReferenceException, 重新獲取 tables
while True:
    try:
#         我試著直接拿到 td 的文字, 但是很遺憾的是雙層迴圈取值速度比不上網頁更新, 
#         data = [ [td.text for td in tr.find_elements_by_css_selector('td')]
#                     for tr in tables[0].find_elements_by_css_selector('tbody > tr')[1:] 
#                     if len(tr.find_elements_by_css_selector('td'))==13]

        # 因此退而求其次, 再 tr 的結點就拿出文字, 等等多花些時間清洗
        data = [ tr.text for tr in tables[0].find_elements_by_css_selector('tbody > tr')[1:] 
                    if len(tr.find_elements_by_css_selector('td'))==13]
        break
    except StaleElementReferenceException:
        tables = [driver.find_elements_by_css_selector(f'{tag} > table')[0] for tag in ['#bflive', '#bflive2', '#bflive3']]

# %%
# 同上 (tables[0])
while True:
    try:
        data1 = [tr.text for tr in tables[1].find_elements_by_css_selector('tbody > tr')
                    if len(tr.find_elements_by_css_selector('td'))==13]
        break
    except StaleElementReferenceException :
        tables = [driver.find_elements_by_css_selector(f'{tag} > table')[0] for tag in ['#bflive', '#bflive2', '#bflive3']]

# %%
# 同上 (tables[0])
while True:
    try:
        data2 = [tr.text for tr in tables[2].find_elements_by_css_selector('tbody > tr')
                    if len(tr.find_elements_by_css_selector('td'))==13]
        break
    except StaleElementReferenceException :
        tables = [driver.find_elements_by_css_selector(f'{tag} > table')[0] for tag in ['#bflive', '#bflive2', '#bflive3']]

# %%
# 首先將三個表合併在一起
data_all = []
for d in [data, data1, data2]:
    data_all.extend(d)

# %%
# 由於等等需要用空白分隔, 因此比分的欄位內的空白需要拿掉
for i, row in enumerate(data_all) :
    if re.search('[0-9] - [0-9]', row):
        data_all[i] = row.replace(' - ', '-')

# %%
# 用空白分隔每一個 tr 的資料
data_all = [d.split(' ') for d in data_all]

# %%
# 清洗拿到的資料
for row in data_all :
    
    # 尚未開始的比賽, 我們需要自己給它一個空值
    if row[2] not in ['上', '中', '下', '完', '']:
        row.insert(2, '')
        
    # 不知道這什麼欄位, 但是這欄位會有空值需要自己塞
    if row[6] == '析':
        row.insert(6, '')
        
    # 最後的三個欄位常常有空值, 同樣自己塞
    if row[-1] == '析':
        row.extend(['']*3)

# %%
# 確定一下我們每筆資料欄位數都正確了
assert len(data_all) == len([d for d in data_all if len(d)==11])

# %%
# 轉換成 DataFrame
df = pd.DataFrame(data=data_all)
# 最後微調一下資料內容
df[1] = df[1]+df[2]
df.drop(columns=2, inplace=True)
df.columns = columns[1:]

# %%
# 順便介紹一下opencc, 這是中文轉換的套件
# 實體化轉換器, 餐數給s2t 是簡轉繁, t2s就是繁轉簡啦
s2t = opencc.OpenCC('s2t')

# 將 columns跟 df都進行轉換
columns = [s2t.convert(col) for col in columns]
df = pd.read_json(
        s2t.convert(
            df.to_json(force_ascii=False)))

# 由於 json格式下沒有順序, 因此我們用一開始的 columns重新排序
df = df[columns[1:]]

# 還有 index也會亂掉, 不要忘記了
df = df.sort_index()

# %%
# 打完收工
df
# Out:
#     11月06日    KO時間            主場球隊       比分          客場球隊     半場 資料     主  \
# 0       敘甲   90+'下         [13]賈柏萊      2-1      警察俱樂部[4]    0-1  析
# 1      沙地甲   90+'下         [19]卡索瑪      1-2    卡赫利塞哈特[11]    1-2  析
# 2      沙地甲   90+'下          [9]瓦沙姆      0-1      阿爾吉魯[17]    0-0  析  0.49
# 3      沙地甲    78'下          [5]德鹹科      1-0        納積蘭[7]    1-0  析
# 4      以乙北    81'下         [4]提比哩亞      3-0   耶路撒冷夏普爾[10]    1-0  析  0.73
# 5       以丙    82'下           聖達拉吉波      4-2     提拉哈卡默爾夏普爾    2-2  析  0.52
# 6       埃超    58'下       [16]諾高莫斯塔      0-2      佩特捷德[15]    0-2  析  0.95
# 7      阿蘇盃    62'下            穆桑納赫      0-0    米爾巴特[阿曼超3]    0-0  析
# 8      阿蘇盃    58'下       [阿曼超5]蘇哈爾      2-1            凡亞    1-1  析
# 9    阿聯U21    54'下          瓦斯爾U21      0-2      阿爾賈茲拉U21    0-1  析  0.95
# 10   阿聯U21    55'下      渡巴阿富查伊拉U21      0-0        阿基曼U21    0-0  析  1.07
# 11   阿聯U21    56'下           酋長U21      0-2  沙巴柏阿爾艾利杜拜U21    0-2  析   0.9
# 12   阿聯U21    54'下         艾爾維達U21      2-0    阿爾富吉拉杜拜U21    2-0  析  1.03
# 13    德西南聯    48'下       [15]緬恩斯B隊      0-0      費雷堡B隊[7]    0-0  析  0.94
# 14     烏幹超    48'下        [15]SC維拉      2-2       坎帕拉市[3]    2-2  析
# 15     英後賽    48'下          維爾港後備隊      1-1         韋根後備隊    1-1  析  0.87
# 16     英後盃    48'下          洛達鹹後備隊      2-1        彼德堡後備隊    2-1  析  0.86
# 17     荷後賽    48'下         幸運薛達後備隊      1-2        飛燕諾後備隊    1-2  析  0.76
# 18     烏拉後    48'下      蒙特維多競賽會後備隊      2-1       波士頓河後備隊    2-1  析  0.85
# 19     烏拉後    48'下    梵尼克斯蒙特維迪歐後備隊      1-0        圖爾克後備隊    1-0  析  0.79
# 20     阿後賽    48'下          防衛者後備隊      0-0        沙士菲後備隊    0-0  析  0.78
# 21     歐青聯    48'下  [意青甲9]1國際米蘭U19      0-1      巴塞隆拿U191    0-1  析  0.91
# 22     歐青聯    48'下      2貝爾格勒紅星U19      0-0       利物浦U192    0-0  析  0.91
# 23     歐青聯    48'下         1摩納哥U19      3-0        布魯日U19    3-0  析  0.75
# 24     友誼賽    48'下      [42]塞爾維亞女足      0-0     俄羅斯女足[26]    0-0  析  0.85
# 25     烏幹超    32'上        [2]布爾比德科      0-0     URA坎帕拉[8]         析
# 26     烏幹超    38'上       [10]恩傑傑大學      0-0       光明之星[4]         析
# 27     烏幹超    34'上     [14]尼亞米塔尤寶來      0-0        金賈[11]         析
# 28     沙灘足    34'上          阿聯酋沙灘足      0-1         埃及沙灘足         析  1.05
# 29     印度超     4'上          [9]普納城      0-0       清奈因[10]         析  0.81
# ..     ...     ...             ...      ...           ...    ... ..   ...
# 267   NCAA   10:30          新墨西哥州立        -        北達高達州立         析
# 268   NCAA   11:00           北列治學院        -          新墨西哥         析
# 269   NCAA   11:00             史丹福        -           西雅圖         析
# 270   NCAA   11:00          聖地牙哥州立        -      阿肯色派恩布拉夫         析
# 271   NCAA   11:00         加州戴維斯分校        -           三藩市         析
# 272   NCAA   11:00            爾灣分校        -           愛達荷         析
# 273   NCAA   11:00             懷俄明        -         聖塔巴巴拉         析
# 274   NCAA   11:00            聖地牙哥        -          韋伯州立         析
# 275   NCAA   11:30             華盛頓        -          西肯塔基         析
# 276    NBA  08:00完              活塞  115-120            熱火  53-53  析
# 277    NBA  08:00完              魔術  102-100            騎士  58-47  析
# 278    NBA  08:00完              溜馬    94-98            火箭  55-53  析
# 279    NBA  08:30完             紐約人  115-116            公牛  47-47  析
# 280    NBA  09:00完              雷霆  122-116            鵜鶘  62-63  析
# 281    NBA  10:00完              爵士  111-124            速龍  54-65  析
# 282    NBA  10:00完              金塊  115-107          塞爾特人  54-56  析
# 283    NBA  11:30完              勇士  117-101            灰熊  58-58  析
# 284    NBA  11:30完              快艇  120-109            木狼  63-59  析
# 285    CBA  19:35完            北京翱龍  132-131          廣州龍獅  66-67  析
# 286    CBA  19:35完           廣東華南虎  142-129           福建鱘  65-71  析
# 287    CBA  19:35完            江蘇大聖  100-125          深圳烈豹  42-67  析
# 288    CBA  19:35完           吉林東北虎  112-102          四川藍鯨  58-49  析
# 289    CBA  19:35完           上海大鯊魚   93-112           北京鴨  46-52  析
# 290    CBA  19:35完            山西猛龍  117-116          浙江金牛  60-59  析
# 291    CBA  19:35完            天津金獅  103-109           江蘇龍  39-37  析
# 292    CBA  19:35完            新疆飛虎  118-111          山東金星  66-53  析
# 293    KBA  18:30完           原州新世代    73-95          昌原獵隼  34-45  析
# 294    KBA  18:30完            首爾雷電    98-99          安養人參  41-47  析
# 295   PPCB  16:30完          黑水精英BA   99-103      麥諾尼亞熱點BA  47-55  析
# 296   PPCB  19:00完           基尼巴BA   111-75        勇士之路BA  50-36  析
#
#         讓球     客
# 0
# 1
# 2        0  1.49
# 3
# 4        0  1.09
# 5        0  1.42
# 6        0  0.93
# 7
# 8
# 9        0  0.87
# 10    1.25  0.75
# 11       0  0.92
# 12     1.5  0.79
# 13       0  0.92
# 14
# 15    0.75  0.95
# 16    -0.5  0.96
# 17   -0.25  1.06
# 18    0.25  0.97
# 19       0  1.03
# 20    -0.5  1.04
# 21   -0.25  0.91
# 22   -0.75  0.91
# 23     0.5  1.07
# 24   -0.25  0.97
# 25
# 26
# 27
# 28       1  0.65
# 29   -0.25  1.03
# ..     ...   ...
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
#
# [297 rows x 10 columns]
